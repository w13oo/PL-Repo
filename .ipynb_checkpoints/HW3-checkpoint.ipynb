# %%
import requests

res = requests.get('https://tw.burberry.com/mini-lola-bag-p80661431')
res.text
# Out:
# '<!DOCTYPE html>\n<html data-application="browse" class="html-element" data-scroll-mode="document" lang="zh-TW" data-device="desktop">\n<head>\n  <title data-react-helmet="true">迷你 Lola 萝纳包 (冷柠檬色) - 女士 | Burberry® 博柏利官网</title>\n  \n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n  <meta name="viewport" content="width=device-width,initial-scale=1,user-scalable=no">\n  <link rel="stylesheet" type="text/css" href="/nrws/browse/c7de668bdd8768c7772cd4d89158671542558273/css/main.551c77c11ef66cdba98f.css">\n<link rel="stylesheet" type="text/css" href="/nrws/browse/c7de668bdd8768c7772cd4d89158671542558273/css/chunks/boss.0e8b9ef4e195712ff2f0.css">\n<link rel="stylesheet" type="text/css" href="/nrws/browse/c7de668bdd8768c7772cd4d89158671542558273/css/chunks/product-details.container.c46ef5ab49ab79146195.css">\n  \n  <link rel="preload" as="script" href="/nrws/browse/c7de668bdd8768c7772cd4d89158671542558273/js/app.c0499dfcc739af5396bd.js" fetchprior
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup.select_one('.product-info-panel__price').text
# Out:
# 'TWD55,000.00'

# %%
import re
country_code = {'tw': 'TWD', 'jp': 'JPY', 'uk': 'GBP', 'us': 'USD', 'kr' : 'KRW'}
for country in country_code:
    res = requests.get(f'https://{country}.burberry.com/mini-lola-bag-p80661431')
    soup = BeautifulSoup(res.text, 'lxml')
    price_text = soup.select_one('.product-info-panel__price').text
    p = float(''.join([e for e in price_text if re.match('[0-9.]', e)]))
    print(p)
# Out:
# 55000.0
# 195800.0
# 1150.0
# 1550.0
# 2150000.0

# %%
import pandas
dfs = pandas.read_html('https://rate.bot.com.tw/xrt?Lang=zh-TW')

# %%
df = dfs[0]
df = df.iloc[:, [0,2]]
df.columns = ['coin', 'price']
df['coin'] = df['coin'].str.extract('.+\((.+)\)')

price_dic = {}
for idx, rec in df.iterrows():
    if rec.price != '-':
        price_dic[rec.coin] = float(rec.price)
price_dic
# Out:
# /var/folders/cn/6lbv2lls3ts2xhdtb72r7w6w0000gn/T/ipykernel_90665/948301763.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['coin'] = df['coin'].str.extract('.+\((.+)\)')
# {'USD': 30.815,
#  'HKD': 3.939,
#  'GBP': 38.83,
#  'AUD': 20.88,
#  'CAD': 23.18,
#  'SGD': 23.21,
#  'CHF': 34.37,
#  'JPY': 0.2303,
#  'SEK': 3.09,
#  'NZD': 19.27,
#  'THB': 0.9488,
#  'PHP': 0.6105,
#  'IDR': 0.00243,
#  'EUR': 33.96,
#  'KRW': 0.02522,
#  'VND': 0.00148,
#  'MYR': 7.371,
#  'CNY': 4.49}

# %%
import re
country_code = {'tw': 'TWD', 'jp': 'JPY', 'uk': 'GBP', 'us': 'USD', 'kr' : 'KRW'}
for country in country_code:
    res = requests.get(f'https://{country}.burberry.com/mini-lola-bag-p80661431')
    soup = BeautifulSoup(res.text, 'lxml')
    price_text = soup.select_one('.product-info-panel__price').text
    p = float(''.join([e for e in price_text if re.match('[0-9.]', e)]))
    print(country ,p *  price_dic.get(country_code.get(country), 1) )
# Out:
# tw 55000.0
# jp 45092.74
# uk 44654.5
# us 47763.25
# kr 54223.0
